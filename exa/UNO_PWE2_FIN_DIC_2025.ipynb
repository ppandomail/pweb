# %% [markdown]
# # UNIVERSIDAD NACIONAL DEL OESTE
# ## Escuela de Informática
# ### PROGRAMACIÓN WEB 2
# #### Profesores: Mag. Ing. Pablo Pandolfo / Anta. Alexander Andrada
# #### Examen Final - Diciembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# 1. Enumérese tres tareas en el **backend** y tres tareas en el **frontend**

# %% [markdown]
# 2. Defínase **API REST**

# %% [markdown]
# 3. Desarróllese una API que devuelva **Buen día**, **Buenas tardes** o **Buenas noches**, según horario obtenido del sistema. Invóquese la API desde un navegador

# %% [markdown]
# 4. Desarróllese una prueba funcional que valide la API anterior

# %% [markdown]
# 5. Explicítese diferencia entre peticiones **GET**, **POST** y **DELETE**
