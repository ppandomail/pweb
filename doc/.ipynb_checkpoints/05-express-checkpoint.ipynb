// %% [markdown]
// # Express

// %% [markdown]
// * Es un framework de Nodejs usado para crear aplicaciones de servidor (web y APIs) usando JS
// * Funciona con Nodejs versión >= 14
// * Cuando desarrollamos aplicaciones con express estamos desarrollando aplicaciones backend.
// * Modelo cliente-servidor
//     * **Cliente**: app que funciona en el navegador (HTML5 + CSS3 + JS)
//     * **Servidor**: lógica por ejemplo: Guardar datos, subir archivos, etc
// * Comunicación protocolo HTTP: Request - Response
// * Sitio: https://expressjs.com/es/

// %% [markdown]
// ## Crear un proyecto nodejs e instalar express

// %% [markdown]
// 1. mkdir myapp
// 1. cd myapp
// 1. npm init -y
// 1. npm i express
// 1. touch index.js  o  en windows: echo > index.js
// 1. gedit index.js

// %%
// Importar el módulo de Express
const express = require('express')

// Crear una instancia de la aplicación Express
const app = express()

// Puerto
const port = 3000

app.get('/', (req, res) => {
  res.send('<h1>Bienvenido</h1>')
})

app.get('/perfil', (req, res) => {
  res.send('<h1>Perfil de usuario</h1>')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// 7. node index.js

// %% [markdown]
// ## Response

// %%
const express = require('express')
const app = express()
const port = 3000

app.get('/', (req, res) => {
  res.sendFile('./static/index2.html', {
    root: __dirname,
  })
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Routing

// %% [markdown]
// * Crear un servidor que puede enviar distintas rutas.
// * Ejemplo: /profile, /dashboard, /product, etc.

// %%
const express = require('express')
const app = express()
const port = 3000

app.get('/', (req, res) => {
  res.send('Bienvenido')
})

app.get('/perfil', (req, res) => {
  res.send('Perfil de usuario')
})

app.get('/clima', (req, res) => {
  res.send('El clima actual es lluvioso')
})

app.use((req, res) => {
  res.status(404).send('La página no existe')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## HTTP methods

// %% [markdown]
// |            |                                                   |
// | --         | --                                                |
// | **GET**    | Cliente trata de obtener algo                     |
// | **POST**   | Cliente envia datos al servidor para guardarlos   |
// | **PUT**    | Cliente trata de actualizar algo                  |
// | **DELETE** | Cliente trata de eliminar algo                    |
//
// * Todas las URLs que se escriban en la barra de direcciones del navegador serán peticiones GET
// * El resto de las peticiones (POST, PUT, DELETE) se prueban por Postman o
// * Instalando en VSC el plugin Thunder Client (aparece un rayo) y un botón New Request

// %%
const express = require('express')
const app = express()
const port = 3000

app.get('/productos', (req, res) => {
  res.send('Lista de productos')
})

app.post('/producto', (req, res) => {
  res.send('Creando producto')
})

app.put('/producto', (req, res) => {
  res.send('Actualizando producto')
})

app.delete('/producto', (req, res) => {
  res.send('Eliminando producto')
})

// Significa que la ruta funciona con métodos get, post, put, delete
app.all('/info', (req, res) => {
  res.send('Información del servidor')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## HTTP Response

// %% [markdown]
// * ¿Qué puede responder el servidor?
//     * texto
//     * archivos html
//     * videos
//     * audios
//     * json
//     * xml
//     * etc.

// %%
app.get('/', (req, res) => {
  res.send('Bienvenido')
})

app.get('/mi_archivo', (req, res) => {
  res.sendFile('./img/meme.jpg', {
    root: __dirname,
  })
})

app.get('/usuario', (req, res) => {
  res.json({ nombre: 'pepe' })
})

app.get('/isAlive', (req, res) => {
  res.sendStatus(204)
})
// 204: Este código significa que el servidor ha procesado con éxito la solicitud, pero no va a devolver ningún contenido

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Request body

// %% [markdown]
// * El cliente puede enviarle al servidor: texto, un objeto json, archivo, datos a partir de un formulario html, etc.
// * Estructura del request y del response:
//     * endpoint: Ruta. Ej: /endpoint
//     * header: Formato de los datos. Ej: json
//     * body: Datos. Ej: {...}

// %%
const express = require('express')
const app = express()
const port = 3000

// Es para que express procese el texto que le envia el cliente. Sin esta línea req.body es undefined
app.use(express.text())

// Es para que express procese el json que le envia el cliente. Sin esta línea req.body es vacio {}
app.use(express.json())

// Es para que express pueda entender los datos que vienen de un formulario.
app.use(express.urlencoded({ extended: false }))

// Probar con el cliente rest (plugin Thunder Client)
// Body -> Text : Bienvenido
app.post('/texto', (req, res) => {
  res.send(`Recibi el texto ${req.body}`)
})

// Probar con el cliente rest (plugin Thunder Client) Body
// Json -> { "email" : "pepe@gmail.com" }
app.post('/usuario', (req, res) => {
  res.send('Nuevo usuario creado con los datos del json')
})

// Probar con el cliente rest (plugin Thunder Client)
// Body -> Form-encode :
// username  "pepe"
// age       18
app.post('/usuario2', (req, res) => {
  res.send('Nuevo usuario creado con los datos del formulario')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Request Params

// %% [markdown]
// * URL que tenga datos
// * Parámetros: valores que pueden ir cambiando
// * Ejemplo: hola/joe, hola/pepe, hola/ana

// %%
const express = require('express')
const app = express()
const port = 3000

app.get('/hola/:nombre', (req, res) => {
  res.send(`Hola ${req.params.nombre}`)
})
// localhost:3000/hola/pepe

app.get('/suma/:x/:y', (req, res) => {
  const x = parseInt(req.params.x)
  const y = parseInt(req.params.y)
  const resultado = x + y
  res.send(`Resultado de la suma: ${resultado}`)
})
// localhost:3000/suma/20/30

// Otra versión para la suma
app.get('/suma2/:x/:y', (req, res) => {
  const { x, y } = req.params
  res.send(`Resultado de la suma: ${parseInt(x) + parseInt(y)}`)
})

app.get('/nombre/:nombre/edad/:edad', (req, res) => {
  const { nombre, edad } = req.params
  res.send(`El usuario ${nombre} tiene ${edad} años`)
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Queries

// %% [markdown]
// * ? es una consulta
// * Ejemplo: hola/pepe?x=20&y=30

// %%
const express = require('express')
const app = express()
const port = 3000

app.get('/suma/:computadora', (req, res) => {
  const { x, y } = req.query
  res.send(`Resultado de la suma para la computadora ${req.params.computadora} es ${parseInt(x) + parseInt(y)}`)
})
// localhost:3000/suma/mac123?x=2&y=3

app.get('/buscar', (req, res) => {
  if (req.query.q === 'libros') res.send('Lista de libros de javascript')
  else res.send('Página normal')
})
// localhost:3000/buscar?q=libros

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Middleware

// %% [markdown]
// | Flujo      |                                                 |
// | --         | --                                              |
// | **normal** | BROWSER ---REQUEST---> /profile                 |
// | **middle** | BROWSER ---REQUEST---> showInfo() ---> /profile |
//
// * Es una función que se ejecute antes de ejecutar la función de cuaquier ruta
// * Por ejemplo para loggear algo

// %%
const express = require('express')
const app = express()
const port = 3000

app.use((req, res, next) => {
  console.log(`URL: ${req.url}  Method: ${req.method}`)
  next() // es una función para que express continue con su flujo normal
})

app.get('/perfil', (req, res) => {
  res.send('Página de perfil')
})

app.get('/info', (req, res) => {
  res.send('Página de información')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Rest API CRUD

// %% [markdown]
// * Es un servidor que tiene ciertas URLs que nos va a permitir procesar datos
// * Ejemplo: aplicación que guarde productos (ejemplo arreglo de JS)
//
// |            |                |
// | --         | --             |
// | **GET**    | /productos     |
// | **POST**   | /productos     |
// | **GET**    | /productos/:id |
// | **PUT**    | /productos/:id |
// | **DELETE** | /productos/:id |

// %%
const express = require('express')
const app = express()
const port = 3000

let productos = []
productos.push({ nombre: 'zapatillas', precio: 20, id: 1 })
productos.push({ nombre: 'notebook', precio: 2000, id: 2 })
productos.push({ nombre: 'lapicera', precio: 5, id: 3 })

app.use(express.json())

app.get('/productos', (req, res) => {
  res.json(productos)
})

app.post('/productos', (req, res) => {
  // se crea un nuevo objeto con id
  const nuevoProducto = { ...req.body, id: productos.at(-1).id + 1 }
  productos.push(nuevoProducto)
  res.send(nuevoProducto)
})

app.put('/productos/:id', (req, res) => {
  const nuevoDato = req.body;
  const productoEncontrado = productos.find(
    (p) => p.id === parseInt(req.params.id)
  )
  if (!productoEncontrado)
    return res.status(200).json({ message: 'Producto no encontrado' })
  productos.map((p) =>
    p.id === parseInt(req.params.id) ? { ...p, ...nuevoDato } : p
  )
  res.json({ message: 'Producto actualizado con éxito' })
})

app.delete('/productos/:id', (req, res) => {
  const productoEncontrado = productos.find(
    (p) => p.id === parseInt(req.params.id)
  )
  if (!productoEncontrado)
    return res.status(200).json({ message: 'Producto no encontrado' })
  productos = productos.filter((p) => p.id !== parseInt(req.params.id))
  res.sendStatus(204)
})

app.get('/productos/:id', (req, res) => {
  const productoEncontrado = productos.find(
    (p) => p.id === parseInt(req.params.id)
  )
  if (!productoEncontrado)
    return res.status(200).json({ message: 'Producto no encontrado' })
  res.json(productoEncontrado)
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Settings

// %% [markdown]
// * Cambiar comportamiento por defecto del framework
// * https://expressjs.com/en/5x/api.html#app.settings.table

// %%
const express = require('express')
const app = express()

// variables seteadas por el programador
app.set('nombre', 'pweb2')
app.set('puerto', 3000)

// variables de express que el programador le cambia el valor
app.set('case sensitive routing', true)

app.get('/', (req, res) => {
  res.send(app.get('nombre'))
})

app.listen(app.get('puerto'))
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Static files

// %% [markdown]
// * Para servir contenido (múltiples archivos)
// * Ejemplo: se crea archivo html, css y js dentro de una carpeta con cualquier nombre (convención es llamarla static o public) y los enlazo con el tag link y script respectivamente.
// * Cuando se quiere enviar la carpeta static, en vez de estar enviando archivo por archivo se le dice a express que toda la carpeta static es pública (accesible desde el browser)

// %%
const express = require('express')
const app = express()
const port = 3000

app.use(express.static('./static'))

app.listen(port)

// Si en el browser pongo https://localhost:3000/ vemos que están los css
// Si abro la consola del navegador está el texto Bienvenido
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Router

// %% [markdown]
// * Dividir una aplicación en múltiples partes
// * Crear múltiples archivos y al final unirlos todos en una sola aplicación

// %%
const express = require('express')
const app = express()
const port = 3000

const HomeRoutes = require('./modules/home_1')
const UserRoutes = require('./modules/users_1')

HomeRoutes(app)
UserRoutes(app)

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Template engine

// %% [markdown]
// * Motor de plantilla
// * Crear múltiples páginas y que todas compartan una misma interface, compartir datos
// * Procesar archivos htmls en el backend y enviarle al frontend estos htmls
// * Módulo ejs: Embedded JavaScript templating
// * Sitio: https://ejs.co/
// * Instalar en el proyecto: npm i ejs
// * Crear en el proyecto la carpeta views y dentro un archivo index.ejs (no tiene porque estar en una carpeta tampoco tiene porque tener extensión ejs)

// %%
const express = require('express')
const path = require('path')
const ejs = require('ejs')
const app = express()
const port = 3000

app.set('view engine', 'ejs')
app.set('views', path.join(__dirname, 'views'))

app.get('/info', (req, res) => {
  res.render('index')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## EJS Parameters

// %%
const express = require('express')
const path = require('path')
const ejs = require('ejs')
const app = express()
const port = 3000

app.set('view engine', 'ejs')
app.set('views', path.join(__dirname, 'views'))

app.get('/info', (req, res) => {
  const unTitulo = 'Mi página creada desde Express'
  // Se le pasan datos desde el servidor al html
  res.render('index_param', { titulo: unTitulo })
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## EJS partials

// %%
const express = require('express')
const path = require('path')
const ejs = require('ejs')
const app = express()
const port = 3000

app.set('view engine', 'ejs')
app.set('views', path.join(__dirname, 'views'))

app.get('/info', (req, res) => {
  const unTitulo = 'Mi página creada desde Express'
  res.render('info', { titulo: unTitulo })
})

app.get('/perfil', (req, res) => {
  res.render('perfil')
})

app.get('/dashboard', (req, res) => {
  res.render('dashboard')
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## EJS sintax

// %%
const express = require('express')
const path = require('path')
const ejs = require('ejs')
const app = express()
const port = 3000

app.set('view engine', 'ejs')
app.set('views', path.join(__dirname, 'views'))

app.get('/', (req, res) => {

  const herramientas = [
    { id: 1, nombre: 'cypress' },
    { id: 2, nombre: 'selenium' }
  ]

  res.render('index_sintax', {
    titulo: 'Página de información',
    estaVivo: true,
    herramientas: herramientas
  })
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Async code

// %% [markdown]
// * Como manejar código que no está en nuestro servidor que podemos consultarlo a otro sistema externo (BD, servidor, etc.)
// * Axios es un Cliente HTTP basado en promesas para el navegador (usa XMLHttpRequests) y nodejs (módulo nativo http)
// * Hace peticiones
// * Instalar módulo axios: npm i axios

// %%
const express = require('express')
const path = require('path')
const ejs = require('ejs')
const axios = require('axios')
const app = express()
const port = 3000

app.set('view engine', 'ejs')
app.set('views', path.join(__dirname, 'views'))

app.get('/post', async (req, res) => {
  const response = await axios.get(
    'https://jsonplaceholder.typicode.com/posts'
  )
  res.render('index_axios', {
    posts: response.data,
  })
})

app.listen(port)
// Out:
// <ref *1> Server {
//   maxHeaderSize: undefined,
//   insecureHTTPParser: undefined,
//   requestTimeout: 300000,
//   headersTimeout: 60000,
//   keepAliveTimeout: 5000,
//   connectionsCheckingInterval: 30000,
//   joinDuplicateHeaders: undefined,
//   rejectNonStandardBodyWrites: false,
//   _events: [Object: null prototype] {
//     request: [Function: app] {
//       _events: [Object: null prototype],
//       _eventsCount: 1,
//       _maxListeners: undefined,
//       setMaxListeners: [Function: setMaxListeners],
//       getMaxListeners: [Function: getMaxListeners],
//       emit: [Function: emit],
//       addListener: [Function: addListener],
//       on: [Function: addListener],
//       prependListener: [Function: prependListener],
//       once: [Function: once],
//       prependOnceListener: [Function: prependOnceListener],
//       removeListener: [Function: removeListener],
//       off: [Function: removeListener],
// ...

// %% [markdown]
// ## Ejercicios

// %% [markdown]
// 1. Desarrollar una api que calcule la edad de una persona dada una fecha de nacimiento

// %%
const express = require('express')
const app = express()
const port = 3000

// YYYY-MM-DD
app.get('/:fecha', (req, res) => {
  const { fecha } = req.params
  const fechaNacimiento = new Date(fecha)
  const fechaActual = new Date()
  console.log(fechaActual.getFullYear())
  const edad = fechaActual.getFullYear() - fechaNacimiento.getFullYear()
  res.status(200).json({ edad })
})

app.listen(port)

// %% [markdown]
// 2. Desarrollar una api que calcule la CUIT de un beneficiario

// %% [markdown]
// 3. Desarrollar una api que calcule la conversión de número a letra. Ejemplo: 99 respuesta: noventa y nueve

// %% [markdown]
// 4. Desarrollar una api que muestre los problemas de accesibilidad web dada una URL. Usar el framework pa11y y calcular de acuerdo a la Legislación Argentina vigente (ONTI), determinando si la página es o no es accesible.

// %% [markdown]
// 5. Desarrollar app login

// %% [markdown]
// 6. Desarrollar app TATETI

// %% [markdown]
// 7. Desarrollar app Facturador (monto, tipo y nro doc obligatorios segun tope de monto). Mostrar ticket y QR
