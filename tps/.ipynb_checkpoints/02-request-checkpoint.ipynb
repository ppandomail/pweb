# %% [markdown]
# # TP Request
# ---

# %% [markdown]
# ## 1. Hacer una solicitud a un sitio web y mostrar el código de respuesta

# %% [markdown]
# ## 2. Obtener datos de una API pública y convertir la respuesta en un diccionario de Python

# %% [markdown]
# ## 3. Buscar información específica usando parámetros GET (ej: buscar en GitHub)

# %% [markdown]
# ## 4. Crear un recurso en una API usando el método POST (ej: 'https://jsonplaceholder.typicode.com/posts')

# %% [markdown]
# ## 5. Robustecer la petición para evitar que el script se cuelgue si el servidor tarda o falla

# %% [markdown]
# ## 6. Descargar una Imagen
