// %% [markdown]
// # TP Express
// ---

// %% [markdown]
// ## 1. API que devuelva la edad de una persona dada una fecha de nacimiento

// %% [markdown]
// ## 2. API que devuelva la CUIT de un beneficiario dado un DNI

// %% [markdown]
// ## 3. API que devuelva en texto un número. Ejemplo: 99 respuesta: noventa y nueve

// %% [markdown]
// ## 4. APP Login

// %% [markdown]
// ## 5. APP Facturador (monto, tipo y nro doc obligatorios según tope de monto). Mostrar ticket y QR

// %% [markdown]
// ## 6. APP Gestión de personas

// %% [markdown]
// ![Gestión de Personas](img/personas.jpg)
